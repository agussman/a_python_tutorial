# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Read in a .csv file straight from the internet (this could also accept a path to a local file)

# %%
csv_path = "https://raw.githubusercontent.com/agussman/a_python_tutorial/master/200_Scripting_Basics/data/ND_airport_runways.csv"

# %%
df = pd.read_csv(csv_path)

# %%
df
# Out:
#      OBJECTID LOCID     SITENO            FULLNAME FAA_ST           UNIQUE_ID  \
# 0           1  ND02  17245.8*A   RICKETYBACK FIELD     ND  17245.8*A  ND17/35
# 1           2   1A2  17249.1*A              ARTHUR     ND  17249.1*A  ND17/35
# 2           3   ASY   17253.*A         ASHLEY MUNI     ND  17253.*A   ND08/26
# 3           4   ASY   17253.*A         ASHLEY MUNI     ND  17253.*A   ND14/32
# 4           5   20U  17256.1*A               BEACH     ND  17256.1*A  ND12/30
# ..        ...   ...        ...                 ...    ...                 ...
# 126        51   7N6   17353.*A  GRENORA CENTENNIAL     ND  17353.*A   ND17/35
# 127       128   ISN  17496.1*A    SLOULIN FLD INTL     ND  17496.1*A  ND02/20
# 128       129   ISN  17496.1*A    SLOULIN FLD INTL     ND  17496.1*A  ND11/29
# 129       130   6L5   17503.*A         WISHEK MUNI     ND  17503.*A   ND14/32
# 130       131  ND26  17244.3*A        GAJEWSKI FLD     ND  17244.3*A  ND18/36
#
#     RWY_ID  RWY_LEN  RWY_WITH RWY_SFC_TY RWY_SFC_TR PAV_CLASS_ RWY_LIGHTS  \
# 0    17/35     2600       100       TURF                              LOW
# 1    17/35     3100        85     TURF-F                             NSTD
# 2    08/26     2825       150     TURF-F
# 3    14/32     4300        60     ASPH-G                              LOW
# 4    12/30     4200        60     ASPH-G       AFSC                   MED
# ..     ...      ...       ...        ...        ...        ...        ...
# 126  17/35     2600       100     TURF-F
# 127  02/20     3453        60     ASPH-F                              MED
# 128  11/29     6650       100     ASPH-F        PFC                   MED
# 129  14/32     3450        60     ASPH-G                             NSTD
# 130  18/36     2300        40       TURF                              LOW
#
#      STFIPS ST_POSTAL  VERSION  SHAPE.LEN
# 0        38        ND        9   0.007454
# 1        38        ND        9   0.008500
# 2        38        ND        9   0.011122
# 3        38        ND        9   0.013180
# 4        38        ND        9   0.014550
# ..      ...       ...      ...        ...
# 126      38        ND        9   0.007128
# 127      38        ND        9   0.010863
# 128      38        ND        9   0.024758
# 129      38        ND        9   0.010827
# 130      38        ND        9   0.005000
#
# [131 rows x 17 columns]

# %%
df.plot.bar(x='FULLNAME', y='RWY_LEN')
# Out:
# <AxesSubplot:xlabel='FULLNAME'>

# %%
df.plot.bar(x='FULLNAME', y='RWY_LEN', figsize=(15,10))
# Out:
# <AxesSubplot:xlabel='FULLNAME'>

# %%
df.boxplot(column=['RWY_LEN'])
# Out:
# <AxesSubplot:>

# %%
df.RWY_LEN.describe()
# Out:
# count      131.000000
# mean      3669.702290
# std       1559.016212
# min       1350.000000
# 25%       2812.500000
# 50%       3300.000000
# 75%       3900.500000
# max      13197.000000
# Name: RWY_LEN, dtype: float64

# %%
df.RWY_LEN.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# ## References
#  * [Simple Data Visualisation with Python and Pandas](https://towardsdatascience.com/simple-data-visualisation-with-pandas-7a7a035bdc39)
#  * [Pandas Visualization](https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html)
